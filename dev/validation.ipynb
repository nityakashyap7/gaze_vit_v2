# %%
from vit_pytorch import ViT
import torch
from GABRIL_utils.utils import load_dataset
import gymnasium as gym
import sys
# import ale_py
from GABRIL_utils import atari_env_manager
sys.path.append('..')
# Out:
# /project2/biyik_1165/nityakas/gaze_vit_v2/.venv/lib/python3.11/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
env = 'Breakout'
seed = 42
datapath = 'dataset/'
conf_type='normal'
train_type = 'normal'
conf_randomness = 0.0
stack = 1
num_episodes = 2
use_gaze = True
gaze_method = 'Reg'
data_source = 'Our'
gaze_mask_sigma=gaze_mask_sigma = 15.0
gaze_mask_coef=gaze_mask_coeff = 0.7

patch_size = (14, 14)

# %%
observations, actions, gaze_masks, gaze_coordinates = load_dataset(
        env=env,
        seed=seed,
        datapath=datapath,
        conf_type=conf_type,
        conf_randomness=conf_randomness,
        stack=stack,
        num_episodes=num_episodes,
        use_gaze=use_gaze,
        data_source=data_source,
        gaze_mask_sigma=gaze_mask_sigma,
        gaze_mask_coef=gaze_mask_coeff                
    )
# Out:
# ...
# 100%|██████████| 2/2 [00:00<00:00, 117.32it/s]

# %%
environment = gym.make(f'ALE/{env}-v5')
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]

# %%
action_names = environment.unwrapped.get_action_meanings() # type: ignore
action_names
# Out:
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT']

# %%
env_name= 'Seaquest'
noop_max= 30
frame_skip= 1
obs_size= 84
terminal_on_life_loss= False
clip_reward= False
action_repeat_probability= 0.0
screen_render_width= 1920
screen_render_height= 1080
render_mode= 'rgb_array'
num_stack= 1
start_fire= False
ram_info= False

# %%
environment = atari_env_manager.create_env()
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]

# %%
action_names = environment.unwrapped.get_action_meanings() # type: ignore
action_names
# Out:
# ['NOOP',
#  'FIRE',
#  'UP',
#  'RIGHT',
#  'LEFT',
#  'DOWN',
#  'UPRIGHT',
#  'UPLEFT',
#  'DOWNRIGHT',
#  'DOWNLEFT',
#  'UPFIRE',
#  'RIGHTFIRE',
#  'LEFTFIRE',
#  'DOWNFIRE',
#  'UPRIGHTFIRE',
#  'UPLEFTFIRE',
#  'DOWNRIGHTFIRE',
#  'DOWNLEFTFIRE']
